# %% [markdown]
# <a href="https://colab.research.google.com/github/chaithrashagu/Internship/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()

# %% [markdown]
# **ploting a graph with providing the  both X and Y axis**

# %%
plt.plot([1,2,3,4],[1,2,6,16])

# %% [markdown]
# **ploting the graph by giving the style to the graph that is colour and the line style and also giving the minimum and maximum values for the x-axis and y-axis**

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16],'ro' )
plt.axis([0, 6, 0, 20])
plt.show()

# %%
import numpy as np
t=np.arange(0.,5.,0.2)
plt.plot(t,t,'r--',t,t**2,'bs',t,t**3,'g^')
plt.show()

# %% [markdown]
# **plotting the graphs with keyword string**

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
data={'a':np.arange(0,30),
      'd':np.random.randint(0,20,20),
      'c':np.random.randn(30)}
data['b']=data['a']+10*np.random.randn(30)
data['c']=np.abs(data['c'])*100

plt.title('scatter plot')
plt.scatter('a','b',c='c',s='d',data=data)
plt.xlabel("entry a")
plt.ylabel('entry b')
plt.show()

# %%
fig=plt.figure()
ax=plt.axes()

# %%
fig=plt.figure()
ax=plt.axes()
x = np.linspace(0, 10, 1000)#1000 numbers between 0 and 10
ax.plot(x, np.sin(x));

# %%
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x));

# %%
#plt.plot(x, np.sin(x - 0), color='blue')        
#plt.plot(x, np.sin(x - 1), color='g')           
#plt.plot(x, np.sin(x - 2), color='0.75')        
plt.plot(x, np.sin(x - 3), color='#FFDD44')     
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) 
plt.plot(x, np.sin(x - 5), color='chartreuse');

# %%
plt.title('linestyle')
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# %%
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');

# %% [markdown]
# **providinng line style and colour of line in the same line**

# %%
plt.plot(x, x + 0,'-g')  # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r');  # dotted red

# %% [markdown]
# **providing the limits for the axes using the function plt.xlim() and plt.ylim()**

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %% [markdown]
# **providing the limits for both axis in single line**

# %%
plt.title('sin graph')
plt.plot(x, np.sin(x),'g')
plt.axis([-1, 11, -1.5, 1.5]);

# %%
#The plt.axis() method goes even beyond this, allowing you to do things like automatically tighten the bounds around the current plot
plt.plot(x, np.sin(x))
plt.axis('tight');

# %%
plt.plot(x, np.sin(x))
plt.axis('equal');

# %% [markdown]
# **pploting the graph by providing the label for linestyle**

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# # scatter plots

# %%
x=np.linspace(0,10,30)
y=np.sin(x)
plt.plot(x,y,':','g');

# %%
rng=np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %%
plt.plot(x,y,'-ok');

# %% [markdown]
# **Additional keyword arguments to plt.plot specify a wide range of properties of the lines and markers:**

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='yellow',
         markeredgecolor='purple',
         markeredgewidth=5)
plt.ylim(-1.2, 1.2);

# %% [markdown]
# Scatter Plots with plt.scatter

# %%
plt.scatter(x, y, marker='o');

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100*features[3], c=iris.target, cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %% [markdown]
# # **HISTOGRAM**

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

data = np.random.randn(1000)

plt.hist(data);

# %% [markdown]
# **customizing the histogram**

# %%
plt.hist(data,bins=30,normed=True,alpha=0.5,histtype='stepfilled',color='steelblue',edgecolor='purple');
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, normed=True, bins=50)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
counts, bin_edges = np.histogram(data, bins=50)
print(counts)
# Out:
# [ 2  0  2  2  2  2  2  3  6 10  9  5 12 14 16 20 22 27 36 37 33 49 47 49
#  50 37 53 42 45 46 42 27 42 31 29 36 23 18 10  9  9  7 11  5  7  4  3  2
#   3  2]

# %% [markdown]
# # **two dimensional histogram**

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=10, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')

# %% [markdown]
# # **customizing plot legends**

# %%
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %%
ax.legend(loc='upper left', frameon=False)
fig

# %%
ax.legend(frameon=False, loc='lower center', ncol=2)
fig

# %%
ax.legend(fancybox=True, framealpha=1, shadow=True, borderpad=1)
fig

# %%
plt.style.use('classic')
# %matplotlib inline

# %%
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)
plt.colorbar();

# %%
plt.imshow(I, cmap='gray');

# %%
from matplotlib.colors import LinearSegmentedColormap

def grayscale_cmap(cmap):
    """Return a grayscale version of the given colormap"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    # convert RGBA to perceived grayscale luminance
    # cf. http://alienryderflex.com/hsp.html
    RGB_weight = [0.299, 0.587, 0.114]
    luminance = np.sqrt(np.dot(colors[:, :3] ** 2, RGB_weight))
    colors[:, :3] = luminance[:, np.newaxis]
        
    return LinearSegmentedColormap.from_list(cmap.name + "_gray", colors, cmap.N)
    

def view_colormap(cmap):
    """Plot a colormap with its grayscale equivalent"""
    cmap = plt.cm.get_cmap(cmap)
    colors = cmap(np.arange(cmap.N))
    
    cmap = grayscale_cmap(cmap)
    grayscale = cmap(np.arange(cmap.N))
    
    fig, ax = plt.subplots(2, figsize=(6, 2),
                           subplot_kw=dict(xticks=[], yticks=[]))
    ax[0].imshow([colors], extent=[0, 10, 0, 1])
    ax[1].imshow([grayscale], extent=[0, 10, 0, 1])

# %%
view_colormap('jet')

# %%
speckles = (np.random.random(I.shape) < 0.01)
I[speckles] = np.random.normal(0, 3, np.count_nonzero(speckles))

plt.figure(figsize=(10, 3.5))

plt.subplot(1, 2, 1)
plt.imshow(I, cmap='RdBu')
plt.colorbar()

plt.subplot(1, 2, 2)
plt.imshow(I, cmap='RdBu')
plt.colorbar(extend='both')
plt.clim(-1, 1);
